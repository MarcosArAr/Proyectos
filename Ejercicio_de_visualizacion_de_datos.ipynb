# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosArAr/Proyectos/blob/main/Ejercicio_de_visualizacion_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/Five Year Cancer Survival Rates in USA.csv")
df
# Out:
#       Survival Rate  Year       Race   Gender  Cancer Type
# 0             0.559  1977  All races  females  All cancers
# 1             0.550  1980  All races  females  All cancers
# 2             0.551  1983  All races  females  All cancers
# 3             0.576  1986  All races  females  All cancers
# 4             0.596  1989  All races  females  All cancers
# ...             ...   ...        ...      ...          ...
# 1882          0.956  1995      White    total      Thyroid
# 1883          0.959  1998      White    total      Thyroid
# 1884          0.969  2001      White    total      Thyroid
# 1885          0.978  2006      White    total      Thyroid
# 1886          0.984  2013      White    total      Thyroid
#
# [1887 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1887 entries, 0 to 1886
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Survival Rate  1666 non-null   float64
#  1   Year           1887 non-null   int64
#  2   Race           1887 non-null   object
#  3   Gender         1887 non-null   object
#  4   Cancer Type    1887 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 73.8+ KB

# %%
df["Survival Rate"].value_counts()
# Out:
# 0.040    11
# 0.050    10
# 0.037    10
# 0.020     9
# 0.130     9
#          ..
# 0.673     1
# 0.632     1
# 0.525     1
# 0.507     1
# 0.860     1
# Name: Survival Rate, Length: 708, dtype: int64

# %%
df["Survival Rate"].mean().round(3)
# Out:
# 0.437

# %%
df["Survival Rate"].median()
# Out:
# 0.391

# %%
df["Survival Rate"].mode()
# Out:
# 0    0.04
# Name: Survival Rate, dtype: float64

# %%
# Debido a que no se tiene la tasa de supervivencia de algunas filas, se procedera a completarlas con el valor de la media.
df[df["Survival Rate"].isna()]
# Out:
#       Survival Rate  Year   Race   Gender  Cancer Type
# 33              NaN  1963  Black  females  All cancers
# 34              NaN  1973  Black  females  All cancers
# 46              NaN  1963  Black    males  All cancers
# 47              NaN  1973  Black    males  All cancers
# 72              NaN  1963  White  females  All cancers
# ...             ...   ...    ...      ...          ...
# 1822            NaN  1963  Black    males      Thyroid
# 1823            NaN  1973  Black    males      Thyroid
# 1824            NaN  1977  Black    males      Thyroid
# 1835            NaN  1963  Black    total      Thyroid
# 1836            NaN  1973  Black    total      Thyroid
#
# [221 rows x 5 columns]

# %% [markdown]
# ## DATA LIMPIO

# %%
df["Survival Rate"].fillna(0.437, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1887 entries, 0 to 1886
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Survival Rate  1887 non-null   float64
#  1   Year           1887 non-null   int64
#  2   Race           1887 non-null   object
#  3   Gender         1887 non-null   object
#  4   Cancer Type    1887 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 73.8+ KB

# %%
df
# Out:
#       Survival Rate  Year       Race   Gender  Cancer Type
# 0             0.559  1977  All races  females  All cancers
# 1             0.550  1980  All races  females  All cancers
# 2             0.551  1983  All races  females  All cancers
# 3             0.576  1986  All races  females  All cancers
# 4             0.596  1989  All races  females  All cancers
# ...             ...   ...        ...      ...          ...
# 1882          0.956  1995      White    total      Thyroid
# 1883          0.959  1998      White    total      Thyroid
# 1884          0.969  2001      White    total      Thyroid
# 1885          0.978  2006      White    total      Thyroid
# 1886          0.984  2013      White    total      Thyroid
#
# [1887 rows x 5 columns]

# %% [markdown]
# ## VISUALIZACION

# %%
df.groupby(["Race","Year","Gender"])[["Survival Rate"]].mean().round(3).unstack(level="Year")
# Out:
#                   Survival Rate                                            \
# Year                       1963   1973   1977   1980   1983   1986   1989
# Race      Gender
# All races females           NaN    NaN  0.418  0.424  0.431  0.447  0.454
#           males             NaN    NaN  0.378  0.383  0.397  0.410  0.428
#           total             NaN    NaN  0.419  0.426  0.437  0.453  0.471
# Black     females         0.320  0.333  0.366  0.369  0.364  0.377  0.409
#           males           0.308  0.338  0.307  0.332  0.359  0.359  0.370
#           total           0.298  0.337  0.372  0.379  0.387  0.401  0.414
# White     females         0.378  0.401  0.418  0.423  0.433  0.450  0.457
#           males           0.345  0.376  0.380  0.385  0.399  0.410  0.431
#           total           0.349  0.392  0.420  0.427  0.440  0.455  0.476
#
#
# Year                1992   1995   1998   2001   2006   2013
# Race      Gender
# ...

# %%
df_gendertotal = df[df["Gender"] != "total"]
df_graf = df_gendertotal[df_gendertotal["Cancer Type"] != "All cancers"]
df_aux = df_graf[df_graf["Race"] != "All races"]
df_aux
# Out:
#       Survival Rate  Year   Race   Gender Cancer Type
# 144           0.240  1963  Black  females     Bladder
# 145           0.270  1973  Black  females     Bladder
# 146           0.381  1977  Black  females     Bladder
# 147           0.401  1980  Black  females     Bladder
# 148           0.470  1983  Black  females     Bladder
# ...             ...   ...    ...      ...         ...
# 1869          0.915  1995  White    males     Thyroid
# 1870          0.913  1998  White    males     Thyroid
# 1871          0.950  2001  White    males     Thyroid
# 1872          0.951  2006  White    males     Thyroid
# 1873          0.965  2013  White    males     Thyroid
#
# [832 rows x 5 columns]

# %%
df_aux_females = df_aux[df_aux["Gender"] == "females"]
df_aux_females
# Out:
#       Survival Rate  Year   Race   Gender Cancer Type
# 144           0.240  1963  Black  females     Bladder
# 145           0.270  1973  Black  females     Bladder
# 146           0.381  1977  Black  females     Bladder
# 147           0.401  1980  Black  females     Bladder
# 148           0.470  1983  Black  females     Bladder
# ...             ...   ...    ...      ...         ...
# 1856          0.969  1995  White  females     Thyroid
# 1857          0.973  1998  White  females     Thyroid
# 1858          0.974  2001  White  females     Thyroid
# 1859          0.985  2006  White  females     Thyroid
# 1860          0.990  2013  White  females     Thyroid
#
# [416 rows x 5 columns]

# %%
df_aux_males = df_aux[df_aux["Gender"] == "males"]
df_aux_males
# Out:
#       Survival Rate  Year   Race Gender Cancer Type
# 157           0.240  1963  Black  males     Bladder
# 158           0.380  1973  Black  males     Bladder
# 159           0.565  1977  Black  males     Bladder
# 160           0.626  1980  Black  males     Bladder
# 161           0.649  1983  Black  males     Bladder
# ...             ...   ...    ...    ...         ...
# 1869          0.915  1995  White  males     Thyroid
# 1870          0.913  1998  White  males     Thyroid
# 1871          0.950  2001  White  males     Thyroid
# 1872          0.951  2006  White  males     Thyroid
# 1873          0.965  2013  White  males     Thyroid
#
# [416 rows x 5 columns]

# %%
df_auxfem = df_aux_females.groupby(["Year"])[["Survival Rate"]].mean().round(3).sort_values(by="Survival Rate")
df_auxfem
# Out:
#       Survival Rate
# Year
# 1963          0.344
# 1973          0.362
# 1977          0.385
# 1980          0.389
# 1983          0.392
# 1986          0.406
# 1992          0.420
# 1989          0.426
# 1995          0.427
# 1998          0.448
# 2001          0.462
# 2006          0.484
# 2013          0.500

# %%
plt.plot(df_auxfem.index , df_auxfem["Survival Rate"].values, color="pink")

# %%
df_auxmal = df_aux_males.groupby(["Year"])[["Survival Rate"]].mean().round(3).sort_values(by="Survival Rate")
df_auxmal
# Out:
#       Survival Rate
# Year
# 1963          0.319
# 1977          0.341
# 1973          0.352
# 1980          0.357
# 1983          0.377
# 1986          0.382
# 1989          0.397
# 1992          0.413
# 1995          0.430
# 1998          0.431
# 2001          0.449
# 2006          0.468
# 2013          0.481

# %%
plt.plot(df_auxmal.index , df_auxmal["Survival Rate"].values, color="blue")

# %%
import matplotlib.pyplot as plt

plt.figure(dpi=80)
plt.plot(df_auxmal.index , df_auxmal["Survival Rate"].values, color="blue", label="Hombres")
plt.plot(df_auxfem.index , df_auxfem["Survival Rate"].values, color="pink", label="Mujeres")
plt.xlabel("Año")
plt.ylabel("Promedio de la tasa de supervivencia")
plt.title("Diferencia de la tasa de supervivencia entre hombres y mujeres según año")
plt.grid()
plt.legend()
plt.show()
